# %%
from thebeatlab import Chord,Note,Song,RecordStore, Player
# Example usage:
record_store = RecordStore("overall.csv")
song = record_store.get_song("a boogie wit da hoodie", "drowning", "intro")
song = record_store.get_song(artist=None, songname="a team", sectiontype=None)
if song:
    print("Song object loaded successfully.")
# Out:
# [0, 2, 3, 5, 7, 8, 11, 12, 14, 15, 17, 19, 20, 23, 24, 26, 27, 29, 31, 32, 35, 36, 38, 39, 41, 43, 44, 47, 48, 50, 51, 53, 55, 56, 59, 60, 62, 63, 65, 67, 68, 71, 72, 74, 75, 77, 79, 80, 83, 84, 86, 87, 89, 91, 92, 95, 96, 98, 99, 101, 103, 104, 107, 108, 110, 111, 113, 115, 116, 119]
# [6, 8, 10, 11, 13, 15, 17, 18, 20, 22, 23, 25, 27, 29, 30, 32, 34, 35, 37, 39, 41, 42, 44, 46, 47, 49, 51, 53, 54, 56, 58, 59, 61, 63, 65, 66, 68, 70, 71, 73, 75, 77, 78, 80, 82, 83, 85, 87, 89, 90, 92, 94, 95, 97, 99, 101, 102, 104, 106, 107, 109, 111, 113, 114, 116, 118, 119, 121, 123, 125]
# Song object loaded successfully.

# %%
# Assuming song is an instance of the Song class
player = Player(bpm=85, instrument_program=42)
player.load_song(song)
audio = player.play_piano()
audio
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
